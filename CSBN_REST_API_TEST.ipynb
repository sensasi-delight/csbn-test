# %% [markdown]
# <a href="https://colab.research.google.com/github/sensasi-delight/csbn-test/blob/main/CSBN_REST_API_TEST.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Initialization
# Import Required Package

# %%
import requests
import json
import pandas

pandas.set_option('display.max_columns', None)
pandas.set_option('display.max_rows', None)
pandas.set_option('display.max_colwidth', None)

# %% [markdown]
# import dataset for test case

# %%
DATASET_FOLDER_URL = 'https://raw.githubusercontent.com/sensasi-delight/csbn-test/main/dataset/'

PRODUCTS = requests.get(DATASET_FOLDER_URL + 'products.json').json()
BATCHES = requests.get(DATASET_FOLDER_URL + 'batches.json').json()
INVOICES = requests.get(DATASET_FOLDER_URL + 'invoices.json').json()
SHIPMENTS = requests.get(DATASET_FOLDER_URL + 'shipments.json').json()

# %% [markdown]
# Test Function Definition

# %%
host_url = "http://128.199.185.208:3000"

column0 = []
column1 = []
column2 = []
column3 = []
column4 = []
column5 = []


def handler(channel, peer, function, data):
  column0.append(channel)
  column1.append(peer)
  column2.append(function)
  column3.append(data)

  if function[:6] == "create":
    url = host_url + "/" + function + "/" + channel + "/" + peer
    response = requests.post(url, json = data).json()
  elif function[:4] == "read":
    url = host_url + "/" + function + "/" + channel + "/" + peer + "/" + data
    response = requests.get(url).json()
  elif function[:6] == "update":
    url = host_url + "/" + function + "/" + channel + "/" + peer + "/" + data['id']
    response = requests.put(url, json = data).json()

  column4.append(response)
  column5.append(response['success'])

# %% [markdown]
# # Test

# %% [markdown]
# First Test

# %%
#case 1a
handler("channel0", "supp1", "createProduct", PRODUCTS[0])

#case 2a
handler("channel0", "supp2", "createProduct", PRODUCTS[1])

#case 3a
handler("channel0", "supp3", "createProduct", PRODUCTS[2])

# %%
#case 4a
handler("channel0", "supp1", "createBatch", BATCHES[0])

#case 5a
handler("channel0", "supp2", "createBatch", BATCHES[1])

#case 6a
handler("channel0", "supp3", "createBatch", BATCHES[2])

# %%
#case 7a
handler("channel1", "supp1", "createInvoice", INVOICES[0])

#case 8a
handler("channel2", "supp2", "createInvoice", INVOICES[1])

#case 9a
handler("channel3", "supp2", "createInvoice", INVOICES[2])

#case 10a
handler("channel4", "supp3", "createInvoice", INVOICES[3])

# %%
#case 11a
handler("channel1", "courier", "createShipment", SHIPMENTS[0])

#case 12a
handler("channel2", "courier", "createShipment", SHIPMENTS[1])

#case 13a
handler("channel3", "courier", "createShipment", SHIPMENTS[1])

#case 14a
handler("channel4", "courier", "createShipment", SHIPMENTS[2])

# %%
#case 15a
handler("channel1", "cust1", "readShipment", "7777772101050001")

#case 16a
handler("channel2", "cust2", "readShipment", "7777772101050002")

#case 17a
handler("channel3", "supp3", "readShipment", "7777772101050002")

#case 18a
handler("channel4", "cust3", "readShipment", "7777772101070001")

# %%
#case 19a
handler("channel1", "cust1", "readInvoice", "111111210105001")

#case 20a
handler("channel2", "cust2", "readInvoice", "222222210105001")

#case 21a
handler("channel3", "supp3", "readInvoice", "222222210105002")

#case 22a
handler("channel4", "cust3", "readInvoice", "333333210107001")

# %%
#case 23a
handler("channel0", "cust1", "readBatch", "11111100000121010301")

#case 24a
handler("channel0", "cust2", "readBatch", "22222200000121010301")

#case 25a
handler("channel0", "supp3", "readBatch", "22222200000121010301")

#case 26a
handler("channel0", "cust3", "readBatch", "33333300000121010501")

# %%
#case 27a
handler("channel0", "cust1", "readProduct", "111111000001")

#case 28a
handler("channel0", "cust2", "readProduct", "222222000001")

#case 29a
handler("channel0", "supp3", "readProduct", "222222000001")

#case 30a
handler("channel0", "cust3", "readProduct", "333333000001")

# %% [markdown]
# Second Test

# %%
#case 1b
handler("channel2", "cust1", "readShipment", "7777772101050002")

#case 2b
handler("channel3", "cust2", "readShipment", "7777772101050002")

#case 3b
handler("channel4", "supp3", "readShipment", "7777772101070001")

#case 4b
handler("channel1", "cust3", "readShipment", "7777772101050001")

# %%
#case 5b
handler("channel2", "cust1", "readInvoice", "222222210105001")

#case 6b
handler("channel3", "cust2", "readInvoice", "222222210105002")

#case 7b
handler("channel4", "supp3", "readInvoice", "333333210107001")

#case 8b
handler("channel1", "cust3", "readInvoice", "111111210105001")

# %%
#case 9b
handler("channel0", "cust1", "readBatch", "22222200000121010301")

#case 10b
handler("channel0", "cust2", "readBatch", "22222200000121010301")

#case 11b
handler("channel0", "supp3", "readBatch", "33333300000121010501")

#case 12b
handler("channel0", "cust3", "readBatch", "11111100000121010301")

# %%
#case 13b
handler("channel0", "cust1", "readProduct", "222222000001")

#case 14b
handler("channel0", "cust2", "readProduct", "222222000001")

#case 15b
handler("channel0", "supp3", "readProduct", "333333000001")

#case 16b
handler("channel0", "cust3", "readProduct", "111111000001")

# %% [markdown]
# Print result

# %%
result = {
    'Channel': column0,
    'Peer': column1,
    'Function': column2,
    'Data Sent': column3,
    'Response': column4,
    'Is Success': column5
}

df = pandas.DataFrame (result, columns = ['Channel', 'Peer', 'Function', 'Data Sent', 'Response', 'Is Success'])
df.to_csv('result.csv')

display(df)
# Out:
#      Channel     Peer        Function  \
# 0   channel0    supp1   createProduct
# 1   channel0    supp2   createProduct
# 2   channel0    supp3   createProduct
# 3   channel0    supp1     createBatch
# 4   channel0    supp2     createBatch
# 5   channel0    supp3     createBatch
# 6   channel1    supp1   createInvoice
# 7   channel2    supp2   createInvoice
# 8   channel3    supp2   createInvoice
# 9   channel4    supp3   createInvoice
# 10  channel1  courier  createShipment
# 11  channel2  courier  createShipment
# 12  channel3  courier  createShipment
# 13  channel4  courier  createShipment
# 14  channel1    cust1    readShipment
# 15  channel2    cust2    readShipment
# 16  channel3    supp3    readShipment
# 17  channel4    cust3    readShipment
# 18  channel1    cust1     readInvoice
# 19  channel2    cust2     readInvoice
# 20  channel3    supp3     readInvoice
# 21  channel4    cust3     readInvoice
# 22  channel0    cust1       readBatch
# 23  channel0    cust2       readBatch
# 24  channel0    supp3       readBatch
# 25  channel0    cust3       readBatch
# 26  channel0    cust1     readProduct
# 27  channel0    cust2     readProduct
# 28  channel0    supp3     readProduct
# 29  channel0    cust3     readProduct
# 30  channel2    cust1    readShipment
# 31  channel3    cust2    readShipment
# 32  channel4    supp3    readShipment
# 33  channel1    cust3    readShipment
# 34  channel2    cust1     readInvoice
# 35  channel3    cust2     readInvoice
# 36  channel4    supp3     readInvoice
# 37  channel1    cust3     readInvoice
# 38  channel0    cust1       readBatch
# 39  channel0    cust2       readBatch
# 40  channel0    supp3       readBatch
# 41  channel0    cust3       readBatch
# 42  channel0    cust1     readProduct
# 43  channel0    cust2     readProduct
# 44  channel0    supp3     readProduct
# 45  channel0    cust3     readProduct
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              Data Sent  \
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   {'id': '111111000001', 'name': 'Carcass Chicken', 'ingredients': ['Chicken'], 'halalCertificateId': '00111111000001', 'manufacturerName': 'Supp1'}
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   {'id': '222222000001', 'name': 'Carcass Chicken', 'ingredients': ['Chicken'], 'halalCertificateId': '00222222000001', 'manufacturerName': 'Supp2'}
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 {'id': '333333000001', 'name': 'Chicken Sausage', 'ingredients': ['Chicken', 'Salt', 'Garlic'], 'halalCertificateId': '00333333000001', 'manufacturerName': 'Supp3'}
# 3                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       {'id': '11111100000121010301', 'product': {'id': '111111000001', 'name': 'Carcass Chicken', 'ingredients': ['chicken'], 'HalalCertificateId': '00011111000001', 'Manufacturer Name': 'Supp1'}, 'qty': 1000, 'ingredients': []}
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       {'id': '22222200000121010301', 'product': {'id': '222222000001', 'name': 'Carcass Chicken', 'ingredients': ['chicken'], 'HalalCertificateId': '00022222000001', 'Manufacturer Name': 'Supp2'}, 'qty': 1500, 'ingredients': []}
# 5                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               {'id': '33333300000121010501', 'product': {'id': '333333000001', 'name': 'Chicken Sausage', 'ingredients': ['Chicken', 'Salt', 'Garlic'], 'HalalCertificateId': '00033333000001', 'Manufacturer Name': 'Supp3'}, 'qty': 2000, 'ingredients': ['22222200000121012000']}
# 6                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           {'id': '111111210105001', 'buyerId': '444444', 'items': [{'batchId': '11111100000121010301', 'qty': 100}]}
# 7                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          {'id': '222222210105001', 'buyerId': '555555', 'items': [{'batchId': '22222200000121010301', 'qty': 1000}]}
# 8                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           {'id': '222222210105002', 'buyerId': '333333', 'items': [{'batchId': '22222200000121010301', 'qty': 500}]}
# 9                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           {'id': '333333210107001', 'buyerId': '666666', 'items': [{'batchId': '33333300000121010501', 'qty': 800}]}
# 10                                                                                                                                                                                                             {'id': '7777772101050001', 'invoices': [{'id': '111111210105001', 'items': [{'batchId': '11111100000121010301', 'qty': 100}]}], 'history': [{'date': '2021-05-01', 'time': '10:00', 'location': 'Pick up at origin'}, {'date': '2021-05-01', 'time': '11:00', 'location': 'Arrived at City A Facility'}, {'date': '2021-05-01', 'time': '12:00', 'location': 'Departed from City A Facility'}, {'date': '2021-05-02', 'time': '03:00', 'location': 'Arrived at City B Facility'}, {'date': '2021-05-02', 'time': '08:00', 'location': 'Departed from City B Facility'}, {'date': '2021-05-02', 'time': '10:00', 'location': 'Arrived at destination'}]}
# 11  {'id': '7777772101050002', 'invoices': [{'id': '222222210105001', 'items': [{'batchId': '22222200000121010301', 'qty': 1000}]}, {'id': '222222210105002', 'items': [{'batchId': '22222200000121010301', 'qty': 500}]}], 'history': [{'date': '2021-05-01', 'time': '16:00', 'location': 'Pick up at origin'}, {'date': '2021-05-01', 'time': '17:00', 'location': 'Arrived at City A Facility'}, {'date': '2021-05-01', 'time': '18:00', 'location': 'Departed from City A Facility'}, {'date': '2021-05-01', 'time': '19:00', 'location': 'Arrived at destination (222222210105002)'}, {'date': '2021-05-01', 'time': '22:00', 'location': 'Arrived at City C Facility'}, {'date': '2021-05-02', 'time': '03:00', 'location': 'Departed from City C Facility'}, {'date': '2021-05-02', 'time': '03:00', 'location': 'Arrived at destination (222222210105001)'}]}
# 12  {'id': '7777772101050002', 'invoices': [{'id': '222222210105001', 'items': [{'batchId': '22222200000121010301', 'qty': 1000}]}, {'id': '222222210105002', 'items': [{'batchId': '22222200000121010301', 'qty': 500}]}], 'history': [{'date': '2021-05-01', 'time': '16:00', 'location': 'Pick up at origin'}, {'date': '2021-05-01', 'time': '17:00', 'location': 'Arrived at City A Facility'}, {'date': '2021-05-01', 'time': '18:00', 'location': 'Departed from City A Facility'}, {'date': '2021-05-01', 'time': '19:00', 'location': 'Arrived at destination (222222210105002)'}, {'date': '2021-05-01', 'time': '22:00', 'location': 'Arrived at City C Facility'}, {'date': '2021-05-02', 'time': '03:00', 'location': 'Departed from City C Facility'}, {'date': '2021-05-02', 'time': '03:00', 'location': 'Arrived at destination (222222210105001)'}]}
# 13                                                                                                                                                                                                             {'id': '7777772101070001', 'invoices': [{'id': '111111210107001', 'items': [{'batchId': '33333300000121010501', 'qty': 800}]}], 'history': [{'date': '2021-07-01', 'time': '10:00', 'location': 'Pick up at origin'}, {'date': '2021-07-01', 'time': '11:00', 'location': 'Arrived at City A Facility'}, {'date': '2021-07-01', 'time': '12:00', 'location': 'Departed from City A Facility'}, {'date': '2021-07-01', 'time': '18:00', 'location': 'Arrived at City C Facility'}, {'date': '2021-07-01', 'time': '19:00', 'location': 'Departed from City C Facility'}, {'date': '2021-07-01', 'time': '20:00', 'location': 'Arrived at destination'}]}
# 14                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    7777772101050001
# 15                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    7777772101050002
# 16                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    7777772101050002
# 17                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    7777772101070001
# 18                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     111111210105001
# 19                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     222222210105001
# 20                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     222222210105002
# 21                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     333333210107001
# 22                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                11111100000121010301
# 23                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                22222200000121010301
# 24                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                22222200000121010301
# 25                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                33333300000121010501
# 26                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        111111000001
# 27                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        222222000001
# 28                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        222222000001
# 29                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        333333000001
# 30                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    7777772101050002
# 31                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    7777772101050002
# 32                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    7777772101070001
# 33                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    7777772101050001
# 34                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     222222210105001
# 35                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     222222210105002
# 36                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     333333210107001
# 37                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     111111210105001
# 38                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                22222200000121010301
# 39                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                22222200000121010301
# 40                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                33333300000121010501
# 41                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                11111100000121010301
# 42                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        222222000001
# 43                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        222222000001
# 44                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        333333000001
# 45                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        111111000001
#
#                                                                                                                                                                              Response  \
# 0                                                                                                                           {'success': True, 'message': 'create Product is success'}
# 1                                                                                                                           {'success': True, 'message': 'create Product is success'}
# 2                                                                                                                           {'success': True, 'message': 'create Product is success'}
# 3                                                                                                                             {'success': True, 'message': 'create Batch is success'}
# 4                                                                                                                             {'success': True, 'message': 'create Batch is success'}
# 5                                                                                                                             {'success': True, 'message': 'create Batch is success'}
# 6                                                                                                                           {'success': True, 'message': 'create Invoice is success'}
# 7                                                                                                                           {'success': True, 'message': 'create Invoice is success'}
# 8                                                                                                                           {'success': True, 'message': 'create Invoice is success'}
# 9                                                                                                                           {'success': True, 'message': 'create Invoice is success'}
# 10                                                                                                                         {'success': True, 'message': 'create Shipment is success'}
# 11                                                                                                                         {'success': True, 'message': 'create Shipment is success'}
# 12                                                                                                                         {'success': True, 'message': 'create Shipment is success'}
# 13                                                                                                                         {'success': True, 'message': 'create Shipment is success'}
# 14  {'success': False, 'message': 'ENOENT: no such file or directory, open '/home/superman/csbn-network/organizations/peerOrganizations/undefined.csbn.net/connection-profile.yaml''}
# 15  {'success': False, 'message': 'ENOENT: no such file or directory, open '/home/superman/csbn-network/organizations/peerOrganizations/undefined.csbn.net/connection-profile.yaml''}
# 16  {'success': False, 'message': 'ENOENT: no such file or directory, open '/home/superman/csbn-network/organizations/peerOrganizations/undefined.csbn.net/connection-profile.yaml''}
# 17  {'success': False, 'message': 'ENOENT: no such file or directory, open '/home/superman/csbn-network/organizations/peerOrganizations/undefined.csbn.net/connection-profile.yaml''}
# 18  {'success': False, 'message': 'ENOENT: no such file or directory, open '/home/superman/csbn-network/organizations/peerOrganizations/undefined.csbn.net/connection-profile.yaml''}
# 19  {'success': False, 'message': 'ENOENT: no such file or directory, open '/home/superman/csbn-network/organizations/peerOrganizations/undefined.csbn.net/connection-profile.yaml''}
# 20  {'success': False, 'message': 'ENOENT: no such file or directory, open '/home/superman/csbn-network/organizations/peerOrganizations/undefined.csbn.net/connection-profile.yaml''}
# 21  {'success': False, 'message': 'ENOENT: no such file or directory, open '/home/superman/csbn-network/organizations/peerOrganizations/undefined.csbn.net/connection-profile.yaml''}
# 22  {'success': False, 'message': 'ENOENT: no such file or directory, open '/home/superman/csbn-network/organizations/peerOrganizations/undefined.csbn.net/connection-profile.yaml''}
# 23  {'success': False, 'message': 'ENOENT: no such file or directory, open '/home/superman/csbn-network/organizations/peerOrganizations/undefined.csbn.net/connection-profile.yaml''}
# 24  {'success': False, 'message': 'ENOENT: no such file or directory, open '/home/superman/csbn-network/organizations/peerOrganizations/undefined.csbn.net/connection-profile.yaml''}
# 25  {'success': False, 'message': 'ENOENT: no such file or directory, open '/home/superman/csbn-network/organizations/peerOrganizations/undefined.csbn.net/connection-profile.yaml''}
# 26  {'success': False, 'message': 'ENOENT: no such file or directory, open '/home/superman/csbn-network/organizations/peerOrganizations/undefined.csbn.net/connection-profile.yaml''}
# 27  {'success': False, 'message': 'ENOENT: no such file or directory, open '/home/superman/csbn-network/organizations/peerOrganizations/undefined.csbn.net/connection-profile.yaml''}
# 28  {'success': False, 'message': 'ENOENT: no such file or directory, open '/home/superman/csbn-network/organizations/peerOrganizations/undefined.csbn.net/connection-profile.yaml''}
# 29  {'success': False, 'message': 'ENOENT: no such file or directory, open '/home/superman/csbn-network/organizations/peerOrganizations/undefined.csbn.net/connection-profile.yaml''}
# 30  {'success': False, 'message': 'ENOENT: no such file or directory, open '/home/superman/csbn-network/organizations/peerOrganizations/undefined.csbn.net/connection-profile.yaml''}
# 31  {'success': False, 'message': 'ENOENT: no such file or directory, open '/home/superman/csbn-network/organizations/peerOrganizations/undefined.csbn.net/connection-profile.yaml''}
# 32  {'success': False, 'message': 'ENOENT: no such file or directory, open '/home/superman/csbn-network/organizations/peerOrganizations/undefined.csbn.net/connection-profile.yaml''}
# 33  {'success': False, 'message': 'ENOENT: no such file or directory, open '/home/superman/csbn-network/organizations/peerOrganizations/undefined.csbn.net/connection-profile.yaml''}
# 34  {'success': False, 'message': 'ENOENT: no such file or directory, open '/home/superman/csbn-network/organizations/peerOrganizations/undefined.csbn.net/connection-profile.yaml''}
# 35  {'success': False, 'message': 'ENOENT: no such file or directory, open '/home/superman/csbn-network/organizations/peerOrganizations/undefined.csbn.net/connection-profile.yaml''}
# 36  {'success': False, 'message': 'ENOENT: no such file or directory, open '/home/superman/csbn-network/organizations/peerOrganizations/undefined.csbn.net/connection-profile.yaml''}
# 37  {'success': False, 'message': 'ENOENT: no such file or directory, open '/home/superman/csbn-network/organizations/peerOrganizations/undefined.csbn.net/connection-profile.yaml''}
# 38  {'success': False, 'message': 'ENOENT: no such file or directory, open '/home/superman/csbn-network/organizations/peerOrganizations/undefined.csbn.net/connection-profile.yaml''}
# 39  {'success': False, 'message': 'ENOENT: no such file or directory, open '/home/superman/csbn-network/organizations/peerOrganizations/undefined.csbn.net/connection-profile.yaml''}
# 40  {'success': False, 'message': 'ENOENT: no such file or directory, open '/home/superman/csbn-network/organizations/peerOrganizations/undefined.csbn.net/connection-profile.yaml''}
# 41  {'success': False, 'message': 'ENOENT: no such file or directory, open '/home/superman/csbn-network/organizations/peerOrganizations/undefined.csbn.net/connection-profile.yaml''}
# 42  {'success': False, 'message': 'ENOENT: no such file or directory, open '/home/superman/csbn-network/organizations/peerOrganizations/undefined.csbn.net/connection-profile.yaml''}
# 43  {'success': False, 'message': 'ENOENT: no such file or directory, open '/home/superman/csbn-network/organizations/peerOrganizations/undefined.csbn.net/connection-profile.yaml''}
# 44  {'success': False, 'message': 'ENOENT: no such file or directory, open '/home/superman/csbn-network/organizations/peerOrganizations/undefined.csbn.net/connection-profile.yaml''}
# 45  {'success': False, 'message': 'ENOENT: no such file or directory, open '/home/superman/csbn-network/organizations/peerOrganizations/undefined.csbn.net/connection-profile.yaml''}
#
#     Is Success
# 0         True
# 1         True
# 2         True
# 3         True
# 4         True
# 5         True
# 6         True
# 7         True
# 8         True
# 9         True
# 10        True
# 11        True
# 12        True
# 13        True
# 14       False
# 15       False
# 16       False
# 17       False
# 18       False
# 19       False
# 20       False
# 21       False
# 22       False
# 23       False
# 24       False
# 25       False
# 26       False
# 27       False
# 28       False
# 29       False
# 30       False
# 31       False
# 32       False
# 33       False
# 34       False
# 35       False
# 36       False
# 37       False
# 38       False
# 39       False
# 40       False
# 41       False
# 42       False
# 43       False
# 44       False
# 45       False
